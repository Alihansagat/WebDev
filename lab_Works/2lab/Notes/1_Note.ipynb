# %% [markdown]
# <h1 align="center">👨🏻‍💻WebDev 1 Note</h1>

# %% [markdown]
# <h3>1️⃣ HTML Attributes</h3>
# <ul>
#     <li>Extra info for elements.</li>
#     <li>Example: &lt;a href="https://google.com"&gt;Google&lt;/a&gt; → href is an attribute.</li>
# </ul>
# <a href="https://google.com" target="_blank">Google</a>
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQT12Ze1dLYl13v7HrxS_V4w9rmiKE1-pGsu9-TPdPzDw1edtZ4MWHySUddbt3m9sfCsKUg&s=10" alt="Cute Cat" width="200">

# %% [markdown]
# <h3> 2️⃣ HTML Styles </h3>
# <ul>
#     <li>Inline CSS: &lt;p style="color:red;"&gt;Hello&lt;/p&gt;</li>
#     <li>Controls color, font, size, alignment.</li>
# </ul>
# <p style="color:blue; font-size:20px;">Styled text</p>

# %% [markdown]
# <h3> 3️⃣ HTML Formatting</h3>
#
# <b>Bold</b><br>
# <i>Italic</i><br>
# <u>Underline</u><br>
# <strong>Important</strong><br>
# <em>Emphasis</em>

# %% [markdown]
# <h3> 4️⃣ HTML Quotations </h3>
#
# <q>This is a short quote.</q> <br>
# <blockquote>This is a long quote.</blockquote> <br>
# <cite>– Author Name</cite>

# %% [markdown]
# <h3> 5️⃣ HTML Comments </h3>
# <p> &lt;!-- This is a comment --&gt; </p>
# <p>Visible text</p>

# %% [markdown]
# <h3> 6️⃣ HTML CSS </h3>
# <ul>
#     <li>Inline, internal, external.</li>
# </ul>
# <br>
# <b>Inline</b>
#
# &lt;p style="color:purple;"&gt;Inline CSS&lt;/p&gt;
#
# <br>
# <br>
#
# <b>Internal</b>
#
# &lt;style&gt;
# <br>
# p { color: orange; font-size: 18px; }
# <br>
# &lt;/style&gt;
#
# <br>
# <br>
#
# <b>External</b>
#
# &lt;link rel="stylesheet" href="style.css"&gt;

# %% [markdown]
# <h3>7️⃣ HTML Links</h3>
# <br>
# &lt;a href="https://google.com" target="_blank"&gt;Google&lt;/a&gt;
# <br>
# &lt;a href="page2.html"&gt;Go to Page 2&lt;/a&gt;

# %% [markdown]
# <h3>8️⃣ HTML Favicon</h3>
# <br>
# &lt;link rel="icon" href="favicon.ico" type="image/x-icon"&gt;

# %% [markdown]
# <h3>9️⃣ HTML Tables</h3>
# <br>
# &lt;table border="1"&gt;
# <br>
#   &lt;tr&gt;
# <br>
#     &lt;th&gt;Name&lt;/th&gt;
# <br>
#     &lt;th&gt;Age&lt;/th&gt;
# <br>
#   &lt;/tr&gt;
# <br>
# &lt;/table&gt;

# %% [markdown]
# <h3>🔟 HTML Lists</h3>
# <!-- Ordered -->
# <ol>
#   <li>First</li>
#   <li>Second</li>
# </ol>
#
# <!-- Unordered -->
# <ul>
#   <li>Apple</li>
#   <li>Banana</li>
# </ul>

# %% [markdown]
# <h3>1️⃣1️⃣ HTML Block & Inline</h3>
# <!-- Block elements -->
# <div>This is a block element.</div>
# <p>Paragraph is also block.</p>
#
# <!-- Inline elements -->
# <span>This is inline.</span>
# <a href="#">Link is inline.</a>

# %% [markdown]
# <h3>1️⃣2️⃣ HTML Div</h3>
# <div style="border:1px solid black; padding:10px;">
#   This is a container.
# </div>

# %% [markdown]
# <h3>1️⃣3️⃣ HTML Classes</h3>
# <p class="text-red">Red paragraph</p>
# <p class="text-red">Another red paragraph</p>
#
# <style>
#   .text-red { color: red; }
# </style>

# %% [markdown]
# <h3>1️⃣4️⃣ HTML Id</h3>
# <p id="unique">Unique paragraph</p>
#
# <style>
#   #unique { color: blue; }
# </style>

# %% [markdown]
# <h3>1️⃣5️⃣ HTML Buttons</h3>
# <button>Click Me</button>
# <button onclick="alert('Hello!')">Click Alert</button>

# %% [markdown]
# <h3>1️⃣6️⃣ HTML Iframes</h3>
# <iframe src="https://example.com" width="300" height="200"></iframe>

# %% [markdown]
# <h3>1️⃣7️⃣ HTML JavaScript</h3>
# <script>
#   console.log("Hello from JavaScript!");
#   alert("Hi!");
# </script>

# %% [markdown]
# <h3>1️⃣8️⃣ HTML Entities</h3>
#
# &lt → <
#
# &gt → >
#
# &amp → &
#
# &quot → "
#
# &apos → '
